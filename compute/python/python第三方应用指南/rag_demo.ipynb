# %% [markdown]
# ## 本地RAG知识库 测试

# %%
from langchain.document_loaders.pdf import PyPDFDirectoryLoader

DATA_PATH = "data"
def load_documents():
    document_loader = PyPDFDirectoryLoader(DATA_PATH)
    return document_loader.load()

documents = load_documents()
print(documents[0])
# Out:
# page_content='版 权信息
# 书
# 作
# 出
# 名：知识大迁移：移动时代知识的真正价值
# 者：【美】威廉·庞德斯通
# 版社：浙江人民出版社·湛庐文化
# 湛庐图书有限公司授权得到 APP电子版制作与发行
# 版权所有·侵权必究
# 此书献给凯西（Kathy），纪念所有美好的时光
# 谎言重复千遍即成真理。
# ※人们常常把这句话错误地安在纳粹德国宣传部部长约瑟夫 ·戈培
# 尔的头上，但实际上不是。
# 前言
# 知识，究竟去了哪里？
# ' metadata={'source': 'data\\test_book.pdf', 'page': 0, 'page_label': '1'}

# %%
from langchain_community.embeddings.ollama import OllamaEmbeddings
from langchain_community.embeddings.bedrock import BedrockEmbeddings
def get_embedding_function():
    embeddings = BedrockEmbeddings(
        credentials_profile_name="default", region_name="us-east-1"
    )
    # embeddings = OllamaEmbeddings(model="nomic-embed-text")
    return embeddings

# %%
from langchain_community.embeddings.ollama import OllamaEmbeddings 
def get_embedding_function(): 
    # embeddings = OllamaEmbeddings(model="nomic-embed-text")
    embeddings = OllamaEmbeddings(model="bge-m3:latest")
    
    return embeddings

# 获取嵌入函数
embedding_function = get_embedding_function()

# 单个文本
text = "这是一个测试文本。"
# 生成嵌入向量
embedding = embedding_function.embed_query(text)
print(f"单个文本的嵌入向量长度: {len(embedding)}")
print(f"单个文本的嵌入向量: {embedding}")
# Out:
# 单个文本的嵌入向量长度: 1024
# 单个文本的嵌入向量: [-1.3956466913223267, 0.830481231212616, -0.6792399883270264, -0.4574785530567169, -0.1730852872133255, -0.976590096950531, 0.6488874554634094, 1.3444691896438599, 0.5408957004547119, 0.5392482876777649, -0.3967168927192688, -0.2159854769706726, 0.13457225263118744, -0.1869591772556305, 0.057215794920921326, -0.5924845337867737, 0.38102036714553833, -0.42295917868614197, -0.17961791157722473, -0.45863959193229675, -1.500720739364624, 0.2238302230834961, 0.40276700258255005, -0.022234123200178146, 0.16392458975315094, 1.1127508878707886, -0.5279603600502014, -0.4562138319015503, 0.2631242573261261, 0.5795977711677551, 1.0479729175567627, -0.24778513610363007, 0.5904390215873718, -1.45216965675354, -0.3799022436141968, -0.5438035130500793, -0.05884818732738495, -1.1291072368621826, -0.8237879276275635, 0.8232311606407166, 0.6111273169517517, -1.1692867279052734, 0.11610080301761627, -1.3542290925979614, 0.07353028655052185, -0.33920660614967346, 0.46711188554763794, -0.8219858407974243, -0.9887574911117554, -0.1259874701499939, -0.33632174134254456, 0.2832348644733429, 1.995192050933838, 0.05986075848340988, 0.10824509710073471, -